# %%
import numpy as np
level = ["<90", "90", "95", "100", "105", "110", "120", "130", "140", "150", "160", "170", "180"]

# %%
counter = 0
for i in range(0, 13):
    counter += 1

print(counter)
# Out:
# 13

# %%
dataraw = "128 128 129 131 132 133 137 137 138 141 143 146 149 129 130 130 133 134 135 138 139 140 142 145 147 151 133 133 134 136 137 138 141 142 143 146 148 151 154 142 142 143 145 146 147 150 151 152 155 157 160 163 143 144 144 147 147 148 152 153 153 156 158 161 164 147 147 147 150 151 152 155 156 157 159 162 164 168 155 156 156 159 160 161 164 165 166 168 171 173 177 157 157 158 160 161 162 165 166 167 170 172 175 178 160 161 161 164 165 165 169 170 170 173 176 178 182 169 170 170 173 173 174 178 179 179 182 185 187 191 171 171 171 174 175 176 179 180 181 183 186 188 192 174 174 175 177 178 179 182 183 184 187 189 192 195 183 183 184 186 187 188 191 192 193 196 198 201 204"

n = 13
data = dataraw.split(" ")
data = [data[i * n:(i + 1) * n] for i in range((len(data) + n - 1) // n )]
data = list(map(list, zip(*data)))

print(data)
# Out:
# [['128', '129', '133', '142', '143', '147', '155', '157', '160', '169', '171', '174', '183'], ['128', '130', '133', '142', '144', '147', '156', '157', '161', '170', '171', '174', '183'], ['129', '130', '134', '143', '144', '147', '156', '158', '161', '170', '171', '175', '184'], ['131', '133', '136', '145', '147', '150', '159', '160', '164', '173', '174', '177', '186'], ['132', '134', '137', '146', '147', '151', '160', '161', '165', '173', '175', '178', '187'], ['133', '135', '138', '147', '148', '152', '161', '162', '165', '174', '176', '179', '188'], ['137', '138', '141', '150', '152', '155', '164', '165', '169', '178', '179', '182', '191'], ['137', '139', '142', '151', '153', '156', '165', '166', '170', '179', '180', '183', '192'], ['138', '140', '143', '152', '153', '157', '166', '167', '170', '179', '181', '184', '193'], ['141', '142', '146', '155', '156', '159', '168', '170', '173', '182', '183', '187', '196'], ['143', '145', '148', '157', '158', '162', '171', '172', '176', '18
# ...

# %%
c = 6
for i in data:
    print('"'+str(c)+'":')
    print("{ ")
    for j in i:
        print('"'+level[i.index(j)]+'": "'+j+'",')
    print(" },")
    c += 1
# Out:
# "6":
# {
# "<90": "128",
# "90": "129",
# "95": "133",
# "100": "142",
# "105": "143",
# "110": "147",
# "120": "155",
# "130": "157",
# "140": "160",
# "150": "169",
# "160": "171",
# "170": "174",
# "180": "183",
#  },
# "7":
# {
# "<90": "128",
# "90": "130",
# "95": "133",
# "100": "142",
# "105": "144",
# "110": "147",
# "120": "156",
# "130": "157",
# "140": "161",
# "150": "170",
# "160": "171",
# "170": "174",
# "180": "183",
#  },
# "8":
# {
# "<90": "129",
# "90": "130",
# "95": "134",
# "100": "143",
# "105": "144",
# "110": "147",
# "120": "156",
# "130": "158",
# "140": "161",
# "150": "170",
# "160": "171",
# "170": "175",
# "180": "184",
#  },
# "9":
# {
# "<90": "131",
# "90": "133",
# "95": "136",
# "100": "145",
# "105": "147",
# "110": "150",
# "120": "159",
# "130": "160",
# "140": "164",
# "150": "173",
# "160": "174",
# "170": "177",
# "180": "186",
#  },
# "10":
# {
# "<90": "132",
# "90": "134",
# "95": "137",
# "100": "146",
# "105": "147",
# "110": "151",
# ...
